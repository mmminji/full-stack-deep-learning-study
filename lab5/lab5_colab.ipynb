# %% [markdown]
# <a href="https://colab.research.google.com/github/mmminji/full-stack-deep-learning-study/blob/master/lab5_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/mmminji/full-stack-deep-learning-study
# Out:
# Cloning into 'full-stack-deep-learning-study'...
# remote: Enumerating objects: 360, done.
# remote: Counting objects: 100% (360/360), done.
# remote: Compressing objects: 100% (286/286), done.
# remote: Total 360 (delta 126), reused 284 (delta 64), pack-reused 0
# Receiving objects: 100% (360/360), 67.85 MiB | 26.17 MiB/s, done.
# Resolving deltas: 100% (126/126), done.

# %%
# %cd full-stack-deep-learning-study/lab5
# Out:
# /content/full-stack-deep-learning-study/lab5

# %%
# !pip install wandb
# !pip install pytorch_lightning
# !pip install boltons
# %env PYTHONPATH=.:$PYTHONPATH
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 5.5 MB/s
# ...
#      |████████████████████████████████| 133 kB 46.5 MB/s
# ...
#      |████████████████████████████████| 170 kB 42.5 MB/s
# ...
#      |████████████████████████████████| 97 kB 6.4 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.8 MB/s
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=f134047e324e1e7ae0509f7dbde590765a18f441f5d98fef03b5a5881a40ad8f
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=a34590005e29e631082c34b74e2087cdfb5fbd97468ddef5beca82b76b119b52
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built subprocess32 pathtools
# ...
#      |████████████████████████████████| 918 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 636 kB 37.7 MB/s
# ...

# %%
# !wandb login
# 780bbd2298f57a220288d36e6967a7990ca3b6c3
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# # ver1

# %%
# !wandb sweep training/sweeps/emnist_lines2_line_cnn_transformer.yml
# Out:
# wandb: Creating sweep from: training/sweeps/emnist_lines2_line_cnn_transformer.yml
# wandb: Created sweep with ID: yfq74itw
# wandb: View sweep at: https://wandb.ai/minji/full-stack-deep-learning-study-lab5_training/sweeps/yfq74itw
# wandb: Run sweep agent with: wandb agent minji/full-stack-deep-learning-study-lab5_training/yfq74itw

# %%
# !wandb agent minji/full-stack-deep-learning-study-lab5_training/yfq74itw
# Out:
# wandb: Starting wandb agent 🕵️
# 2021-08-25 14:05:44,055 - wandb.wandb_agent - INFO - Running runs: []
# 2021-08-25 14:05:45,182 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-08-25 14:05:45,182 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	conv_dim: 64
# 	data_class: EMNISTLines2
# 	fc_dim: 1024
# 	gpus: -1
# 	loss: transformer
# 	lr: 0.01
# 	model_class: LineCNNTransformer
# 	num_workers: 20
# 	precision: 16
# 	tf_dim: 256
# 	tf_fc_dim: 1024
# 	tf_layers: 6
# 	tf_nhead: 4
# 	window_stride: 8
# 	window_width: 8
# 2021-08-25 14:05:45,186 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python training/run_experiment.py --wandb --conv_dim=64 --data_class=EMNISTLines2 --fc_dim=1024 --gpus=-1 --loss=transformer --lr=0.01 --model_class=LineCNNTransformer --num_workers=20 --precision=16 --tf_dim=256 --tf_fc_dim=1024 --tf_layers=6 --tf_nhead=4 --window_stride=8 --window_width=8
# ...

# %% [markdown]
# # ver2

# %%
# !wandb sweep training/sweeps/emnist_lines2_line_cnn_transformer.yml

# %%
# !wandb agent minji/full-stack-deep-learning-study-lab5_training/4zg865rp

# %% [markdown]
# # ver3

# %%
# !wandb sweep training/sweeps/emnist_lines2_line_cnn_transformer2.yml
# Out:
# wandb: Creating sweep from: training/sweeps/emnist_lines2_line_cnn_transformer2.yml
# wandb: Created sweep with ID: dlumsg9m
# wandb: View sweep at: https://wandb.ai/minji/full-stack-deep-learning-study-lab5_training/sweeps/dlumsg9m
# wandb: Run sweep agent with: wandb agent minji/full-stack-deep-learning-study-lab5_training/dlumsg9m

# %%
# !wandb agent minji/full-stack-deep-learning-study-lab5_training/dlumsg9m
# Out:
# wandb: Starting wandb agent 🕵️
# 2021-08-31 10:29:51,794 - wandb.wandb_agent - INFO - Running runs: []
# 2021-08-31 10:29:51,938 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-08-31 10:29:51,938 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	conv_dim: 32
# 	data_class: EMNISTLines2
# 	fc_dim: 1024
# 	gpus: -1
# 	loss: transformer
# 	lr: 0.01
# 	max_epochs: 40
# 	model_class: LineCNNTransformer
# 	num_workers: 20
# 	precision: 16
# 	tf_dim: 128
# 	tf_fc_dim: 256
# 	tf_layers: 4
# 	tf_nhead: 4
# 	window_stride: 8
# 	window_width: 16
# 2021-08-31 10:29:51,942 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python training/run_experiment.py --wandb --conv_dim=32 --data_class=EMNISTLines2 --fc_dim=1024 --gpus=-1 --loss=transformer --lr=0.01 --max_epochs=40 --model_class=LineCNNTransformer --num_workers=20 --precision=16 --tf_dim=128 --tf_fc_dim=256 --tf_layers=4 --tf_nhead=4 --window_stride=8 --window_width=16
# ...
