# %%
# !python text_recognizer/data/iam_lines.py
# Out:
# Cropping IAM line regions...
# ...
# Computing SHA-256...
# Extracting IAM data
# Saving images, labels, and statistics...
# IAM Lines Dataset
# Num classes: 83
# Dims: (1, 56, 2048)
# Output dims: (89, 1)
# Train/val/test sizes: 9116, 2279, 1958
# Train Batch x stats: (torch.Size([128, 1, 56, 2048]), torch.float32, tensor(0.), tensor(0.0187), tensor(0.0806), tensor(1.))
# Train Batch y stats: (torch.Size([128, 89]), torch.int64, tensor(1), tensor(82))
# Test Batch x stats: (torch.Size([128, 1, 56, 2048]), torch.float32, tensor(0.), tensor(0.0137), tensor(0.0591), tensor(0.9294))
# Test Batch y stats: (torch.Size([128, 89]), torch.int64, tensor(1), tensor(81))
# 0.00B [00:00, ?B/s]
#   0%|          | 8.00k/586M [00:01<39:14:37, 4.35kB/s]
#   0%|          | 56.0k/586M [00:02<4:40:13, 36.6kB/s]
#   0%|          | 104k/586M [00:02<2:18:41, 73.9kB/s]
#   0%|          | 240k/586M [00:02<49:21, 207kB/s]
#   0%|          | 496k/586M [00:02<20:40, 495kB/s]
# ...

# %% [markdown]
# ## wandb

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: minji (use `wandb login --relogin` to force relogin)

# %%
# !python training/run_experiment.py --wandb --max_epochs=40 --gpus=1 --num_workers=4 --data_class=EMNISTLines2 --model_class=LineCNNTransformer --loss=transformer
# Out:
# EMNISTLines2 loading data from HDF5...
# EMNISTLines2 loading data from HDF5...
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': tensor(0.8891, device='cuda:0'),
#  'test_cer': tensor(0.1891, device='cuda:0')}
# --------------------------------------------------------------------------------
# Best model saved at: training\logs\full-stack-deep-learning-study-lab5_training\2w91f1ab\checkpoints\epoch=039-val_loss=0.507-val_cer=0.236.ckpt
# wandb: Currently logged in as: minji (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.12.0
# wandb: Syncing run denim-snowflake-11
# wandb:  View project at https://wandb.ai/minji/full-stack-deep-learning-study-lab5_training
# wandb:  View run at https://wandb.ai/minji/full-stack-deep-learning-study-lab5_training/runs/2w91f1ab
# ...

# %%
# !python training/run_experiment.py --wandb --max_epochs=40 --gpus=1 --num_workers=4 --data_class=EMNISTLines2 --model_class=LineCNNTransformer --loss=transformer --precision=16
# Out:
# EMNISTLines2 loading data from HDF5...
# EMNISTLines2 loading data from HDF5...
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': tensor(0.9254, device='cuda:0'),
#  'test_cer': tensor(0.1136, device='cuda:0')}
# --------------------------------------------------------------------------------
# Best model saved at: training\logs\full-stack-deep-learning-study-lab5_training\1glhttl6\checkpoints\epoch=039-val_loss=0.400-val_cer=0.167.ckpt
# wandb: Currently logged in as: minji (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.12.0
# wandb: Syncing run fancy-sponge-20
# wandb:  View project at https://wandb.ai/minji/full-stack-deep-learning-study-lab5_training
# wandb:  View run at https://wandb.ai/minji/full-stack-deep-learning-study-lab5_training/runs/1glhttl6
# ...
