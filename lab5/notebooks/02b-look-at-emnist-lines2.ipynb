# %%
import os
os.environ['CUDA_VISIBLE_DEVICE'] = ''

import argparse

# %matplotlib inline
import matplotlib.pyplot as plt
import nltk
import numpy as np

# %load_ext autoreload
# %autoreload 2

from importlib.util import find_spec
if find_spec("text_recognizer") is None:
    import sys
    sys.path.append('..')

from text_recognizer.data import EMNISTLines2

# %% [markdown]
# ## More challenging EMNISTLines
#
# Now that we've seen the `IAMLines` dataset, we can make our synthetic dataset look more like it by changing the shape of the canvas into which we embed the sentence crops, and by adding data augmentations.

# %%
dataset = EMNISTLines2(args=argparse.Namespace())
dataset.prepare_data()
dataset.setup()
print(dataset)
# Out:
# EMNISTLines2 generating data for train...
# EMNISTLines2 generating data for val...
# EMNISTLines2 generating data for test...
# EMNISTLines2 loading data from HDF5...
# C:\Users\a\anaconda3\envs\fsdl\lib\site-packages\torchvision\transforms\functional_tensor.py:876: UserWarning: Argument fill/fillcolor is not supported for Tensor input. Fill value is zero
#   warnings.warn("Argument fill/fillcolor is not supported for Tensor input. Fill value is zero")
# EMNISTLines2 Dataset
# Min overlap: 0.2
# Max overlap: 0.5
# Num classes: 83
# Dims: (1, 56, 1024)
# Output dims: (89, 1)
# Train/val/test sizes: 10000, 2000, 2000
# Batch x stats: (torch.Size([128, 1, 56, 1024]), torch.float32, tensor(0.), tensor(0.0207), tensor(0.1106), tensor(0.9983))
# Batch y stats: (torch.Size([128, 89]), torch.int64, tensor(1), tensor(66))

# %%
def convert_y_label_to_string(y, dataset=dataset):
    # NOTE: we ignore padding tokens
    return ''.join([dataset.mapping[i] for i in y if i != 3])

y_example = dataset.data_train[0][1]
print(y_example, y_example.shape)
convert_y_label_to_string(y_example)
# Out:
# tensor([ 1, 55, 47, 40, 58, 44, 66, 54, 45, 66, 27, 44, 62, 40, 57, 50, 66, 62,
#         48, 51, 51,  2,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#          3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#          3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#          3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3]) torch.Size([89])
# '<S>phase of Newark will<E>'

# %%
## Train

X, Y = next(iter(dataset.train_dataloader()))
for i in range(10):
    x, y = X[i], Y[i]
    sentence = convert_y_label_to_string(y) 
    plt.matshow(x.squeeze(), cmap='gray', vmin=0, vmax=1)
    plt.title(sentence)

# %%
## Test

X, Y = next(iter(dataset.test_dataloader()))
for i in range(10):
    x, y = X[i], Y[i]
    sentence = convert_y_label_to_string(y) 
    plt.matshow(x.squeeze(), cmap='gray', vmin=0, vmax=1)
    plt.title(sentence)

# %% [markdown]
# ## See predictions of a trained model

# %%
import argparse
from text_recognizer.lit_models import TransformerLitModel
from text_recognizer.models import LineCNNTransformer

model = LineCNNTransformer(
    data_config=dataset.config(),
    args=argparse.Namespace()
)
lit_model = TransformerLitModel.load_from_checkpoint(
    '../training/logs/default_fsdl-text-recognizer-2021-training/469_3ocpqryn/checkpoints/epoch=125-step=5039.ckpt',
    model=model,
    args=argparse.Namespace()
)

for i in range(5):
    x, y = dataset.data_train[i]
    pred = lit_model(x.unsqueeze(0))
    pred_sentence = ''.join(dataset.mapping[_] for _ in pred[0].tolist() if _ != 3)
    true_sentence = convert_y_label_to_string(y) 
    plt.matshow(x.squeeze(), cmap='gray', vmin=0, vmax=1)
    plt.title(pred_sentence)
    
for i in range(5):
    x, y = dataset.data_test[i]
    pred = lit_model(x.unsqueeze(0))
    pred_sentence = ''.join(dataset.mapping[_] for _ in pred[0].tolist() if _ != 3)
    true_sentence = convert_y_label_to_string(y) 
    plt.matshow(x.squeeze(), cmap='gray', vmin=0, vmax=1)
    plt.title(pred_sentence)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-80da12b3a467> in <module>
#      10     '../training/logs/default_fsdl-text-recognizer-2021-training/469_3ocpqryn/checkpoints/epoch=125-step=5039.ckpt',
#      11     model=model,
# ---> 12     args=argparse.Namespace()
#      13 )
#      14
#
# ~\anaconda3\envs\fsdl\lib\site-packages\pytorch_lightning\core\saving.py in load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#     134             checkpoint = pl_load(checkpoint_path, map_location=map_location)
#     135         else:
# --> 136             checkpoint = pl_load(checkpoint_path, map_location=lambda storage, loc: storage)
#     137
#     138         if hparams_file is not None:
#
# ~\anaconda3\envs\fsdl\lib\site-packages\pytorch_lightning\utilities\cloud_io.py in load(path_or_url, map_location)
#      29         return torch.hub.load_state_dict_from_url(str(path_or_url), map_location=map_location)
#      30     fs = get_filesystem(path_or_url)
# ---> 31     with fs.open(path_or_url, "rb") as f:
#      32         return torch.load(f, map_location=map_location)
#      33
#
# ~\anaconda3\envs\fsdl\lib\site-packages\fsspec\spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#     980                 autocommit=ac,
#     981                 cache_options=cache_options,
# --> 982                 **kwargs,
#     983             )
#     984             if not ac and "r" not in mode:
#
# ~\anaconda3\envs\fsdl\lib\site-packages\fsspec\implementations\local.py in _open(self, path, mode, block_size, **kwargs)
#     143         if self.auto_mkdir and "w" in mode:
#     144             self.makedirs(self._parent(path), exist_ok=True)
# --> 145         return LocalFileOpener(path, mode, fs=self, **kwargs)
#     146
#     147     def touch(self, path, **kwargs):
#
# ~\anaconda3\envs\fsdl\lib\site-packages\fsspec\implementations\local.py in __init__(self, path, mode, autocommit, fs, compression, **kwargs)
#     234         self.compression = get_compression(path, compression)
#     235         self.blocksize = io.DEFAULT_BUFFER_SIZE
# --> 236         self._open()
#     237
#     238     def _open(self):
#
# ~\anaconda3\envs\fsdl\lib\site-packages\fsspec\implementations\local.py in _open(self)
#     239         if self.f is None or self.f.closed:
#     240             if self.autocommit or "w" not in self.mode:
# --> 241                 self.f = open(self.path, mode=self.mode)
#     242                 if self.compression:
#     243                     compress = compr[self.compression]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:/Users/a/OneDrive - 고려대학교/GITHUB/full-stack-deep-learning-study/lab5/training/logs/default_fsdl-text-recognizer-2021-training/469_3ocpqryn/checkpoints/epoch=125-step=5039.ckpt'
